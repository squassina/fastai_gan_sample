# %%
from fastai.vision import *
from fastai.vision.gan import *
from fastai.vision.all import *

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
path = './data'

# %%
size=64
bs=128

# %%
dblock = DataBlock(blocks = (TransformBlock, ImageBlock),
                   get_x = generate_noise,
                   get_items = get_image_files,
                   splitter = IndexSplitter([]),
                   item_tfms=Resize((size,size), method=ResizeMethod.Squish), 
                   batch_tfms = Normalize.from_stats(torch.tensor([0.5,0.5,0.5]), torch.tensor([0.5,0.5,0.5])))

# %%
dls = dblock.dataloaders(path, path=path, bs=bs)

# %%
dls.show_batch(max_n=16)

# %%
generator = basic_generator(out_size=size, n_channels=3, n_extra_layers=1)
critic    = basic_critic   (in_size=size, n_channels=3, n_extra_layers=1, act_cls=partial(nn.LeakyReLU, negative_slope=0.2))

# %%
learn = GANLearner.wgan(dls, generator, critic, opt_func = RMSProp)

# %%
learn.recorder.train_metrics=True
learn.recorder.valid_metrics=False

# %%
learn.fit(60, 2e-4, wd=0.)
# Out:
# /home/ricardo/miniconda3/envs/torch/lib/python3.8/site-packages/fastai/callback/core.py:50: UserWarning: You are shadowing an attribute (generator) that exists in the learner. Use `self.learn.generator` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# /home/ricardo/miniconda3/envs/torch/lib/python3.8/site-packages/fastai/callback/core.py:50: UserWarning: You are shadowing an attribute (critic) that exists in the learner. Use `self.learn.critic` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# /home/ricardo/miniconda3/envs/torch/lib/python3.8/site-packages/fastai/callback/core.py:50: UserWarning: You are shadowing an attribute (gen_mode) that exists in the learner. Use `self.learn.gen_mode` to avoid this
# ...

# %%
learn.show_results(max_n=30, ds_idx=0)
